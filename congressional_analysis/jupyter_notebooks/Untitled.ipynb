# %%
cd ../python_scripts/
# Out:
# /Users/amlvt225/Code/GitHub/bb_consulting_public/congressional_analysis/python_scripts

# %%
from RSS_feed_converter import RSSURLToDataFrame

# %%
HEALTH = "https://www.google.com/alerts/feeds/02061760130182022939/16026963312871264927"
HEALTH_PATH = "/Users/amlvt225/Code/GitHub/bb_consulting_public/congressional_analysis/data/google_alerts_health.xml"

ok = RSSURLToDataFrame(url=HEALTH,
                 filepath=HEALTH_PATH)

ok.run()

# %%
ok.data
# Out:
#                                                 title  \
# 0   Telling Police Where People With COVID-19 Live...
# 1   Smart Tags Can Help Hospitals Track Coronaviru...
# 2   ONC Projects Aim to Standardize SDOH Data for ...
# 3   <b>Healthcare</b> Industry Implications of the...
# 4   CAPS, Care Team offering virtual mental <b>hea...
# 5   Pompeo presses Chinese counterpart for needed ...
# 6   DFR requires insurers to cover COVID-19 diagno...
# 7   FDA approves COVID-19 innovations; Ohio State ...
# 8   A Public <b>Health</b> Professor&#39;s Take on...
# 9   An open letter from Richmond region <b>health<...
# 10  Tech optimization: Perfecting pop <b>health</b...
# 11  Gateway <b>Health</b> to Make <b>Medical</b> C...
# 12  How Would ObamaCare Have Handled the Coronavir...
# 13  Montreal opens 2020 bike-<b>sharing</b> season...
# 14  Better Business Bureau Says Stop <b>Sharing</b...
# 15  <b>Sharing</b> your senior portrait online? BB...
# ...
